# %%
x='false'

if x=='false':
    print('x was true')
else :
    print('i will be printed in any case if x is not true')
# Out:
# x was true

# %%
loc='iit'

if loc=='srm':
    print('sorry you are in wrong college')
elif loc=='iit':
    print('welcome to iit')
else :
    print('you are from which college')
# Out:
# welcome to iit

# %%
person='ajeet'

if person=='shubham':
    print('welcome shubham')
elif person=='akshay':
    print('welcome akshay')
else:
    print('whats your name')
# Out:
# whats your name
